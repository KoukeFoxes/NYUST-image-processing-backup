# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
imgL = cv2.imread('Images01/tsukuba_l.png',0)
imgR = cv2.imread('Images01/tsukuba_r.png',0)
stereo = cv2.StereoBM_create(numDisparities=16, blockSize=15)
disparity = stereo.compute(imgL,imgR)
print(disparity[0:100,0:100])
plt.imshow(disparity,'gray')
plt.show()
# Out:
# [[-16 -16 -16 ... -16 -16 -16]
#  [-16 -16 -16 ... -16 -16 -16]
#  [-16 -16 -16 ... -16 -16 -16]
#  ...
#  [-16 -16 -16 ...  81  82  83]
#  [-16 -16 -16 ...  81  82  83]
#  [-16 -16 -16 ...  82  82  84]]

# %%
plt.imshow(imgL,'gray')
plt.show()

# %%
plt.imshow(imgR,'gray')
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
imgL = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Lesson04_IP.rar (Unzipped Files)/Images_New/HusL.png',0)
imgR = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Lesson04_IP.rar (Unzipped Files)/Images_New/HusR.png',0)
stereo = cv2.StereoBM_create(numDisparities=16, blockSize=15)
disparity = stereo.compute(imgL,imgR)
plt.imshow(disparity,'gray')
plt.show()
